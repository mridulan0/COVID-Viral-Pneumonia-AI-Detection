# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential, model_from_json, Model
from keras.layers import Conv2D, MaxPooling2D, MaxPool2D, Dropout, Activation, Flatten, Dense, BatchNormalization, ZeroPadding2D
from keras.optimizers import Adam
from keras import backend as k
import tensorflow as tf

import os
import shutil

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !unzip "/content/gdrive/MyDrive/Science Fair/Synopsis Science Fair Project 2021/Dataset_-20210215T213906Z-001.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: Dataset_/COVID-19/COVID (131).png
#   inflating: Dataset_/COVID-19/COVID (562).png
#   inflating: Dataset_/COVID-19/COVID (627).png
#   inflating: Dataset_/COVID-19/COVID (522).png
#   inflating: Dataset_/COVID-19/COVID (236).png
#   inflating: Dataset_/COVID-19/COVID (174).png
#   inflating: Dataset_/COVID-19/COVID (260).png
#   inflating: Dataset_/COVID-19/COVID (2).png
#   inflating: Dataset_/COVID-19/COVID (165).png
#   inflating: Dataset_/COVID-19/COVID (303).png
#   inflating: Dataset_/COVID-19/COVID (149).png
#   inflating: Dataset_/COVID-19/COVID (16).png
#   inflating: Dataset_/COVID-19/COVID (404).png
#   inflating: Dataset_/COVID-19/COVID (42).png
#   inflating: Dataset_/COVID-19/COVID (38).png
#   inflating: Dataset_/COVID-19/COVID (497).png
#   inflating: Dataset_/COVID-19/COVID (466).png
#   inflating: Dataset_/COVID-19/COVID (469).png
#   inflating: Dataset_/COVID-19/COVID (571).png
#   inflating: Dataset_/COVID-19/COVID (423).png
#   inflating: Dataset_/COVID-19/COVID (567).png
#   inflating: Dataset_/COVID-19/COVID (480).png
#   inflating: Dataset_/COVID-19/COVID (419).png
#   inflating: Dataset_/COVID-19/COVID (670).png
#   inflating: Dataset_/COVID-19/COVID (525).png
#   inflating: Dataset_/COVID-19/COVID (257).png
#   inflating: Dataset_/COVID-19/COVID (209).png
#   inflating: Dataset_/COVID-19/COVID (59).png
#   inflating: Dataset_/COVID-19/COVID (19).png
#   inflating: Dataset_/COVID-19/COVID (262).png
#   inflating: Dataset_/COVID-19/COVID (342).png
#   inflating: Dataset_/COVID-19/COVID (534).png
#   inflating: Dataset_/COVID-19/COVID (418).png
#   inflating: Dataset_/Bacterial Pneumonia/Q_person1668_bacteria_4420.jpeg
#   inflating: Dataset_/COVID-19/COVID (499).png
#   inflating: Dataset_/COVID-19/COVID (299).png
#   inflating: Dataset_/COVID-19/COVID (15).png
#   inflating: Dataset_/COVID-19/COVID (345).png
#   inflating: Dataset_/COVID-19/COVID (422).png
#   inflating: Dataset_/COVID-19/COVID (498).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (318).png
#   inflating: Dataset_/COVID-19/COVID (64).png
#   inflating: Dataset_/COVID-19/COVID (445).png
#   inflating: Dataset_/COVID-19/COVID (483).png
#   inflating: Dataset_/COVID-19/COVID (52).png
#   inflating: Dataset_/Normal/N NNORMAL (1226).png
#   inflating: Dataset_/Normal/N NNORMAL (1244).png
#   inflating: Dataset_/COVID-19/COVID (44).png
#   inflating: Dataset_/COVID-19/COVID (412).png
#   inflating: Dataset_/Normal/N NNORMAL (124).png
#   inflating: Dataset_/COVID-19/COVID (424).png
#   inflating: Dataset_/COVID-19/COVID (266).png
#   inflating: Dataset_/Normal/N NNORMAL (1207).png
#   inflating: Dataset_/COVID-19/COVID (156).png
#   inflating: Dataset_/Normal/N NNORMAL (121).png
#   inflating: Dataset_/Normal/N NNORMAL (1233).png
#   inflating: Dataset_/Normal/N NNORMAL (120).png
#   inflating: Dataset_/Normal/N NNORMAL (1234).png
#   inflating: Dataset_/Normal/N NNORMAL (1242).png
#   inflating: Dataset_/Normal/N NNORMAL (1236).png
#   inflating: Dataset_/Normal/N NNORMAL (1166).png
#   inflating: Dataset_/Normal/N NNORMAL (1237).png
#   inflating: Dataset_/Normal/N NNORMAL (1246).png
#   inflating: Dataset_/Normal/N NNORMAL (1220).png
#   inflating: Dataset_/Normal/N NNORMAL (1206).png
#   inflating: Dataset_/Normal/N NNORMAL (1198).png
#   inflating: Dataset_/Normal/N NNORMAL (1171).png
#   inflating: Dataset_/Normal/N NNORMAL (1164).png
#   inflating: Dataset_/Normal/N NNORMAL (1232).png
#   inflating: Dataset_/Normal/N NNORMAL (1190).png
#   inflating: Dataset_/Normal/N NNORMAL (1172).png
#   inflating: Dataset_/Normal/N NNORMAL (117).png
#   inflating: Dataset_/COVID-19/COVID (450).png
#   inflating: Dataset_/Normal/N NNORMAL (1225).png
#   inflating: Dataset_/Normal/N NNORMAL (1208).png
#   inflating: Dataset_/COVID-19/COVID (35).png
#   inflating: Dataset_/Normal/N NNORMAL (1247).png
#   inflating: Dataset_/Normal/N NNORMAL (1229).png
#   inflating: Dataset_/Normal/N NNORMAL (1185).png
#   inflating: Dataset_/Normal/N NNORMAL (1187).png
#   inflating: Dataset_/Normal/N NNORMAL (1250).png
#   inflating: Dataset_/Normal/N NNORMAL (1186).png
#   inflating: Dataset_/Normal/N NNORMAL (1182).png
#   inflating: Dataset_/Normal/N NNORMAL (1218).png
#   inflating: Dataset_/Normal/N NNORMAL (1235).png
#   inflating: Dataset_/Normal/N NNORMAL (1192).png
#   inflating: Dataset_/Normal/N NNORMAL (1176).png
#   inflating: Dataset_/Normal/N NNORMAL (118).png
#   inflating: Dataset_/Normal/N NNORMAL (1243).png
#   inflating: Dataset_/Normal/N NNORMAL (1195).png
#   inflating: Dataset_/Normal/N NNORMAL (1169).png
#   inflating: Dataset_/Normal/N NNORMAL (1180).png
#   inflating: Dataset_/Normal/N NNORMAL (1163).png
#   inflating: Dataset_/Normal/N NNORMAL (1181).png
#   inflating: Dataset_/Normal/N NNORMAL (1197).png
#   inflating: Dataset_/Normal/N NNORMAL (1210).png
#   inflating: Dataset_/Normal/N NNORMAL (119).png
#   inflating: Dataset_/Normal/N NNORMAL (1161).png
#   inflating: Dataset_/Normal/N NNORMAL (1196).png
#   inflating: Dataset_/Normal/N NNORMAL (1162).png
#   inflating: Dataset_/Normal/N NNORMAL (1179).png
#   inflating: Dataset_/Normal/N NNORMAL (1168).png
#   inflating: Dataset_/Normal/N NNORMAL (1202).png
#   inflating: Dataset_/Normal/N NNORMAL (1147).png
#   inflating: Dataset_/Normal/N NNORMAL (1178).png
#   inflating: Dataset_/Normal/N NNORMAL (1184).png
#   inflating: Dataset_/Normal/N NNORMAL (1174).png
#   inflating: Dataset_/Normal/N NNORMAL (1238).png
#   inflating: Dataset_/Normal/N NNORMAL (1139).png
#   inflating: Dataset_/Normal/N NNORMAL (1165).png
#   inflating: Dataset_/Normal/N NNORMAL (1170).png
#   inflating: Dataset_/Normal/N NNORMAL (115).png
#   inflating: Dataset_/Normal/N NNORMAL (1191).png
#   inflating: Dataset_/Normal/N NNORMAL (1183).png
#   inflating: Dataset_/Normal/N NNORMAL (1159).png
#   inflating: Dataset_/Normal/N NNORMAL (1175).png
#   inflating: Dataset_/Normal/N NNORMAL (1158).png
#   inflating: Dataset_/Normal/N NNORMAL (1157).png
#   inflating: Dataset_/Normal/N NNORMAL (1136).png
#   inflating: Dataset_/Normal/N NNORMAL (1128).png
#   inflating: Dataset_/Normal/N NNORMAL (1135).png
#   inflating: Dataset_/Normal/N NNORMAL (1173).png
#   inflating: Dataset_/Normal/N NNORMAL (1167).png
#   inflating: Dataset_/Normal/N NNORMAL (1193).png
#   inflating: Dataset_/Normal/N NNORMAL (1194).png
#   inflating: Dataset_/Normal/N NNORMAL (12).png
#   inflating: Dataset_/Normal/N NNORMAL (1200).png
#   inflating: Dataset_/Normal/N NNORMAL (1154).png
#   inflating: Dataset_/Normal/N NNORMAL (1160).png
#   inflating: Dataset_/Normal/N NNORMAL (1201).png
#   inflating: Dataset_/Normal/N NNORMAL (1132).png
#   inflating: Dataset_/Normal/N NNORMAL (1177).png
#   inflating: Dataset_/Normal/N NNORMAL (1189).png
#   inflating: Dataset_/Normal/N NNORMAL (1113).png
#   inflating: Dataset_/Normal/N NNORMAL (116).png
#   inflating: Dataset_/Normal/N NNORMAL (1131).png
#   inflating: Dataset_/Normal/N NNORMAL (1123).png
#   inflating: Dataset_/Normal/N NNORMAL (1150).png
#   inflating: Dataset_/Normal/N NNORMAL (1140).png
#   inflating: Dataset_/Normal/N NNORMAL (1110).png
#   inflating: Dataset_/Normal/N NNORMAL (1199).png
#   inflating: Dataset_/COVID-19/COVID (376).png
#   inflating: Dataset_/Normal/N NNORMAL (1151).png
#   inflating: Dataset_/COVID-19/COVID (357).png
#   inflating: Dataset_/COVID-19/COVID (274).png
#   inflating: Dataset_/COVID-19/COVID (371).png
#   inflating: Dataset_/COVID-19/COVID (21).png
#   inflating: Dataset_/Normal/N NNORMAL (1188).png
#   inflating: Dataset_/Normal/N NNORMAL (114).png
#   inflating: Dataset_/Normal/N NNORMAL (1143).png
#   inflating: Dataset_/Normal/N NNORMAL (1130).png
#   inflating: Dataset_/COVID-19/COVID (208).png
#   inflating: Dataset_/Normal/N NNORMAL (1156).png
#   inflating: Dataset_/Normal/N NNORMAL (1120).png
#   inflating: Dataset_/COVID-19/COVID (178).png
#   inflating: Dataset_/COVID-19/COVID (1196).png
#   inflating: Dataset_/COVID-19/COVID (337).png
#   inflating: Dataset_/Normal/N NNORMAL (1141).png
#   inflating: Dataset_/Normal/N NNORMAL (1117).png
#   inflating: Dataset_/COVID-19/COVID (654).png
#   inflating: Dataset_/COVID-19/COVID (473).png
#   inflating: Dataset_/COVID-19/COVID (569).png
#   inflating: Dataset_/COVID-19/COVID (1194).png
#   inflating: Dataset_/Normal/N NNORMAL (1137).png
#   inflating: Dataset_/Normal/N NNORMAL (111).png
#   inflating: Dataset_/COVID-19/COVID (557).png
#   inflating: Dataset_/COVID-19/COVID (177).png
#   inflating: Dataset_/COVID-19/COVID (529).png
#   inflating: Dataset_/COVID-19/COVID (478).png
#   inflating: Dataset_/COVID-19/COVID (179).png
#   inflating: Dataset_/COVID-19/COVID (406).png
#   inflating: Dataset_/COVID-19/COVID (639).png
#   inflating: Dataset_/COVID-19/COVID (644).png
#   inflating: Dataset_/COVID-19/COVID (432).png
#   inflating: Dataset_/COVID-19/COVID (472).png
#   inflating: Dataset_/Normal/N NNORMAL (1114).png
#   inflating: Dataset_/COVID-19/COVID (127).png
#   inflating: Dataset_/COVID-19/COVID (592).png
#   inflating: Dataset_/COVID-19/COVID (622).png
#   inflating: Dataset_/COVID-19/COVID (249).png
#   inflating: Dataset_/Normal/N NNORMAL (1112).png
#   inflating: Dataset_/COVID-19/COVID (441).png
#   inflating: Dataset_/COVID-19/COVID (580).png
#   inflating: Dataset_/COVID-19/COVID (363).png
#   inflating: Dataset_/COVID-19/COVID (382).png
#   inflating: Dataset_/COVID-19/COVID (219).png
#   inflating: Dataset_/Normal/N NNORMAL (112).png
#   inflating: Dataset_/Normal/N NNORMAL (1126).png
#   inflating: Dataset_/Normal/N NNORMAL (1148).png
#   inflating: Dataset_/Normal/N NNORMAL (1111).png
#   inflating: Dataset_/COVID-19/COVID (223).png
#   inflating: Dataset_/COVID-19/COVID (285).png
#   inflating: Dataset_/Normal/N NNORMAL (1145).png
#   inflating: Dataset_/COVID-19/COVID (188).png
#   inflating: Dataset_/COVID-19/COVID (350).png
#   inflating: Dataset_/COVID-19/COVID (595).png
#   inflating: Dataset_/COVID-19/COVID (66).png
#   inflating: Dataset_/COVID-19/COVID (271).png
#   inflating: Dataset_/Normal/N NNORMAL (1129).png
#   inflating: Dataset_/Normal/N NNORMAL (1121).png
#   inflating: Dataset_/Normal/N NNORMAL (1122).png
#   inflating: Dataset_/COVID-19/COVID (198).png
#   inflating: Dataset_/COVID-19/COVID (137).png
#   inflating: Dataset_/Normal/N NNORMAL (1119).png
#   inflating: Dataset_/Normal/N NNORMAL (1133).png
#   inflating: Dataset_/Normal/N NNORMAL (1125).png
#   inflating: Dataset_/COVID-19/COVID (611).png
#   inflating: Dataset_/COVID-19/COVID (417).png
#   inflating: Dataset_/Normal/N NNORMAL (1153).png
#   inflating: Dataset_/Normal/N NNORMAL (1146).png
#   inflating: Dataset_/Normal/N NNORMAL (1144).png
#   inflating: Dataset_/Normal/N NNORMAL (1134).png
#   inflating: Dataset_/COVID-19/COVID (195).png
#   inflating: Dataset_/Normal/N NNORMAL (1115).png
#   inflating: Dataset_/COVID-19/COVID (67).png
#   inflating: Dataset_/Normal/N NNORMAL (1152).png
#   inflating: Dataset_/COVID-19/COVID (393).png
#   inflating: Dataset_/Normal/N NNORMAL (1149).png
#   inflating: Dataset_/COVID-19/COVID (1191).png
#   inflating: Dataset_/Normal/N NNORMAL (113).png
#   inflating: Dataset_/COVID-19/COVID (465).png
#   inflating: Dataset_/COVID-19/COVID (248).png
#   inflating: Dataset_/COVID-19/COVID (134).png
#   inflating: Dataset_/COVID-19/COVID (234).png
#   inflating: Dataset_/COVID-19/COVID (318).png
#   inflating: Dataset_/COVID-19/COVID (233).png
#   inflating: Dataset_/COVID-19/COVID (668).png
#   inflating: Dataset_/COVID-19/COVID (215).png
#   inflating: Dataset_/Normal/N NNORMAL (1118).png
#   inflating: Dataset_/COVID-19/COVID (575).png
#   inflating: Dataset_/COVID-19/COVID (542).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (754).png
#   inflating: Dataset_/Normal/N NNORMAL (1215).png
#   inflating: Dataset_/COVID-19/COVID (633).png
#   inflating: Dataset_/COVID-19/COVID (194).png
#   inflating: Dataset_/COVID-19/COVID (307).png
#   inflating: Dataset_/COVID-19/COVID (203).png
#   inflating: Dataset_/Normal/N NNORMAL (1138).png
#   inflating: Dataset_/Normal/N NNORMAL (1155).png
#   inflating: Dataset_/Bacterial Pneumonia/Q_person1035_bacteria_2969.jpeg
#   inflating: Dataset_/COVID-19/COVID (381).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (737).png
#   inflating: Dataset_/COVID-19/COVID (308).png
#   inflating: Dataset_/COVID-19/COVID (442).png
#   inflating: Dataset_/COVID-19/COVID (390).png
#   inflating: Dataset_/COVID-19/COVID (282).png
#   inflating: Dataset_/COVID-19/COVID (536).png
#   inflating: Dataset_/COVID-19/COVID (158).png
#   inflating: Dataset_/COVID-19/COVID (651).png
#   inflating: Dataset_/Normal/N NNORMAL (1127).png
#   inflating: Dataset_/COVID-19/COVID (756).png
#   inflating: Dataset_/COVID-19/COVID (863).png
#   inflating: Dataset_/COVID-19/COVID (798).png
#   inflating: Dataset_/Bacterial Pneumonia/Q_person1473_bacteria_3836.jpeg
#   inflating: Dataset_/Normal/N NNORMAL (468).png
#   inflating: Dataset_/Normal/N NNORMAL (596).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (543).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (214).png
#   inflating: Dataset_/Normal/N NNORMAL (621).png
#   inflating: Dataset_/Bacterial Pneumonia/Q_person305_bacteria_1437.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person907_bacteria_2832.jpeg
#   inflating: Dataset_/COVID-19/COVID (532).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1248).png
#   inflating: Dataset_/Normal/N NNORMAL (135).png
#   inflating: Dataset_/Bacterial Pneumonia/Q_person75_bacteria_366.jpeg
#   inflating: Dataset_/COVID-19/COVID (36).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (216).png
#   inflating: Dataset_/Normal/N NNORMAL (1216).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (202).png
#   inflating: Dataset_/Normal/N NNORMAL (438).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (524).png
#   inflating: Dataset_/Normal/N NNORMAL (234).png
#   inflating: Dataset_/Bacterial Pneumonia/Q_person1493_bacteria_3899.jpeg
#   inflating: Dataset_/COVID-19/COVID (854).png
#   inflating: Dataset_/COVID-19/COVID (955).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (628).png
#   inflating: Dataset_/COVID-19/COVID (619).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (541).png
#   inflating: Dataset_/COVID-19/COVID (92).png
#   inflating: Dataset_/Bacterial Pneumonia/Q_person23_bacteria_89.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person9_bacteria_40.jpeg
#   inflating: Dataset_/Normal/N NNORMAL (238).png
#   inflating: Dataset_/COVID-19/COVID (742).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (344).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (504).png
#   inflating: Dataset_/COVID-19/COVID (259).png
#   inflating: Dataset_/Bacterial Pneumonia/Q_person1847_bacteria_4716.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (757).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (346).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (133).png
#   inflating: Dataset_/COVID-19/COVID (340).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (727).png
#   inflating: Dataset_/COVID-19/COVID (941).png
#   inflating: Dataset_/Normal/N NNORMAL (615).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (717).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (238).png
#   inflating: Dataset_/Normal/N NNORMAL (603).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (537).png
#   inflating: Dataset_/Normal/N NNORMAL (47).png
#   inflating: Dataset_/Normal/N NNORMAL (610).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (721).png
#   inflating: Dataset_/Bacterial Pneumonia/Q_person1628_bacteria_4294.jpeg
#   inflating: Dataset_/COVID-19/COVID (697).png
#   inflating: Dataset_/COVID-19/COVID (355).png
#   inflating: Dataset_/Bacterial Pneumonia/Q_person347_bacteria_1595.jpeg
#   inflating: Dataset_/COVID-19/COVID (895).png
#   inflating: Dataset_/Normal/N NNORMAL (226).png
#   inflating: Dataset_/Normal/N NNORMAL (1251).png
#   inflating: Dataset_/Normal/N NNORMAL (209).png
#   inflating: Dataset_/Bacterial Pneumonia/Q_person1880_bacteria_4765.jpeg
#   inflating: Dataset_/Normal/N NNORMAL (1105).png
#   inflating: Dataset_/COVID-19/COVID (807).png
#   inflating: Dataset_/Normal/N NNORMAL (1088).png
#   inflating: Dataset_/Normal/N NNORMAL (1061).png
#   inflating: Dataset_/Normal/N NNORMAL (1094).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (490).png
#   inflating: Dataset_/Bacterial Pneumonia/Q_person535_bacteria_2255.jpeg
#   inflating: Dataset_/Normal/N NNORMAL (109).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1247).png
#   inflating: Dataset_/COVID-19/COVID (905).png
#   inflating: Dataset_/Normal/N NNORMAL (1084).png
#   inflating: Dataset_/Normal/N NNORMAL (1109).png
#   inflating: Dataset_/Normal/N NNORMAL (1064).png
#   inflating: Dataset_/Bacterial Pneumonia/Q_person1408_bacteria_3579.jpeg
#   inflating: Dataset_/Normal/N NNORMAL (190).png
#   inflating: Dataset_/Normal/N NNORMAL (1106).png
#   inflating: Dataset_/Normal/N NNORMAL (1080).png
#   inflating: Dataset_/Normal/N NNORMAL (1100).png
#   inflating: Dataset_/Bacterial Pneumonia/Q_person1365_bacteria_3489.jpeg
#   inflating: Dataset_/Normal/N NNORMAL (1103).png
#   inflating: Dataset_/Normal/N NNORMAL (1098).png
#   inflating: Dataset_/Bacterial Pneumonia/Q_person707_bacteria_2606.jpeg
#   inflating: Dataset_/Normal/N NNORMAL (110).png
#   inflating: Dataset_/Bacterial Pneumonia/Q_person1065_bacteria_2999.jpeg
#   inflating: Dataset_/Normal/N NNORMAL (1090).png
#   inflating: Dataset_/Normal/N NNORMAL (107).png
#   inflating: Dataset_/Bacterial Pneumonia/Q_person368_bacteria_1672.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person23_bacteria_80.jpeg
#   inflating: Dataset_/Normal/N NNORMAL (1062).png
#   inflating: Dataset_/Bacterial Pneumonia/Q_person1385_bacteria_3524.jpeg
#   inflating: Dataset_/Normal/N NNORMAL (1078).png
#   inflating: Dataset_/Bacterial Pneumonia/Q_person480_bacteria_2040.jpeg
#   inflating: Dataset_/Normal/N NNORMAL (1073).png
#   inflating: Dataset_/Normal/N NNORMAL (1074).png
#   inflating: Dataset_/Normal/N NNORMAL (1068).png
#   inflating: Dataset_/Normal/N NNORMAL (1083).png
#   inflating: Dataset_/Normal/N NNORMAL (1097).png
#   inflating: Dataset_/Bacterial Pneumonia/Q_person974_bacteria_2899.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person315_bacteria_1464.jpeg
#   inflating: Dataset_/Normal/N NNORMAL (1099).png
#   inflating: Dataset_/Normal/N NNORMAL (1082).png
#   inflating: Dataset_/Bacterial Pneumonia/Q_person1922_bacteria_4830.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person942_bacteria_2867.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person1760_bacteria_4602.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person1128_bacteria_3069.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person531_bacteria_2239.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person568_bacteria_2358.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person45_bacteria_220.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person371_bacteria_1698.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person1067_bacteria_3001.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person421_bacteria_1852.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person684_bacteria_2580.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person325_bacteria_1501.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person1005_bacteria_2936.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person1770_bacteria_4614.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person531_bacteria_2242.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person826_bacteria_2737.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person61_bacteria_297.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person331_bacteria_1528.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person1933_bacteria_4844.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person387_bacteria_1769.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person551_bacteria_2310.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person475_bacteria_2020.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person1306_bacteria_3276.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person436_bacteria_1883.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person309_bacteria_1447.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person75_bacteria_364.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person1471_bacteria_3831.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person441_bacteria_1900.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person30_bacteria_156.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person56_bacteria_269.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person295_bacteria_1389.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person1576_bacteria_4122.jpeg
#   inflating: Dataset_/Normal/N NNORMAL (11).png
#   inflating: Dataset_/Bacterial Pneumonia/Q_person1765_bacteria_4608.jpeg
#   inflating: Dataset_/Normal/N NNORMAL (1102).png
#   inflating: Dataset_/Bacterial Pneumonia/Q_person258_bacteria_1212.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person71_bacteria_349.jpeg
#   inflating: Dataset_/Normal/N NNORMAL (1087).png
#   inflating: Dataset_/Normal/N NNORMAL (1092).png
#   inflating: Dataset_/Bacterial Pneumonia/Q_person629_bacteria_2508.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person1436_bacteria_3711.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person1022_bacteria_2953.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person73_bacteria_355.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person1906_bacteria_4803.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person1007_bacteria_2938.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person1663_bacteria_4412.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person1584_bacteria_4146.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person298_bacteria_1409.jpeg
#   inflating: Dataset_/Normal/N NNORMAL (1019).png
#   inflating: Dataset_/Normal/N NNORMAL (1057).png
#   inflating: Dataset_/Bacterial Pneumonia/Q_person655_bacteria_2547.jpeg
#   inflating: Dataset_/Normal/N NNORMAL (1095).png
#   inflating: Dataset_/Bacterial Pneumonia/Q_person1667_bacteria_4417.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person1268_bacteria_3227.jpeg
#   inflating: Dataset_/Normal/N NNORMAL (1089).png
#   inflating: Dataset_/Normal/N NNORMAL (1028).png
#   inflating: Dataset_/Bacterial Pneumonia/Q_person422_bacteria_1853.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person1493_bacteria_3896.jpeg
#   inflating: Dataset_/Normal/N NNORMAL (1037).png
#   inflating: Dataset_/Normal/N NNORMAL (1072).png
#   inflating: Dataset_/Normal/N NNORMAL (1022).png
#   inflating: Dataset_/Normal/N NNORMAL (1031).png
#   inflating: Dataset_/Bacterial Pneumonia/Q_person441_bacteria_1916.jpeg
#   inflating: Dataset_/COVID-19/COVID (521).png
#   inflating: Dataset_/COVID-19/COVID (747).png
#   inflating: Dataset_/COVID-19/COVID (86).png
#   inflating: Dataset_/Bacterial Pneumonia/Q_person1298_bacteria_3261.jpeg
#   inflating: Dataset_/Normal/N NNORMAL (606).png
#   inflating: Dataset_/Normal/N NNORMAL (1054).png
#   inflating: Dataset_/Bacterial Pneumonia/Q_person31_bacteria_161.jpeg
#   inflating: Dataset_/Normal/N NNORMAL (1045).png
#   inflating: Dataset_/Normal/N NNORMAL (1043).png
#   inflating: Dataset_/Normal/N NNORMAL (1048).png
#   inflating: Dataset_/Normal/N NNORMAL (1050).png
#   inflating: Dataset_/Bacterial Pneumonia/Q_person545_bacteria_2287.jpeg
#   inflating: Dataset_/COVID-19/COVID (210).png
#   inflating: Dataset_/Normal/N NNORMAL (1041).png
#   inflating: Dataset_/Normal/N NNORMAL (104).png
#   inflating: Dataset_/COVID-19/COVID (848).png
#   inflating: Dataset_/Normal/N NNORMAL (1047).png
#   inflating: Dataset_/Normal/N NNORMAL (1023).png
#   inflating: Dataset_/Bacterial Pneumonia/Q_person741_bacteria_2644.jpeg
#   inflating: Dataset_/Normal/N NNORMAL (1020).png
#   inflating: Dataset_/Normal/N NNORMAL (1030).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (212).png
#   inflating: Dataset_/Bacterial Pneumonia/Q_person897_bacteria_2822.jpeg
#   inflating: Dataset_/Normal/N NNORMAL (1059).png
#   inflating: Dataset_/Normal/N NNORMAL (1049).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (37).png
#   inflating: Dataset_/COVID-19/COVID (859).png
#   inflating: Dataset_/Normal/N NNORMAL (1039).png
#   inflating: Dataset_/Normal/N NNORMAL (1052).png
#   inflating: Dataset_/Normal/N NNORMAL (1055).png
#   inflating: Dataset_/Normal/N NNORMAL (1042).png
#   inflating: Dataset_/Normal/N NNORMAL (1038).png
#   inflating: Dataset_/Normal/N NNORMAL (1026).png
#   inflating: Dataset_/Normal/N NNORMAL (1058).png
#   inflating: Dataset_/Normal/N NNORMAL (1027).png
#   inflating: Dataset_/Normal/N NNORMAL (100).png
#   inflating: Dataset_/Normal/N NNORMAL (1032).png
#   inflating: Dataset_/Normal/N NNORMAL (1040).png
#   inflating: Dataset_/Normal/N NNORMAL (105).png
#   inflating: Dataset_/Normal/N NNORMAL (1035).png
#   inflating: Dataset_/Normal/N NNORMAL (1018).png
#   inflating: Dataset_/Normal/N NNORMAL (1002).png
#   inflating: Dataset_/Normal/N NNORMAL (1017).png
#   inflating: Dataset_/Normal/N NNORMAL (106).png
#   inflating: Dataset_/Normal/N NNORMAL (10).png
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0309-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0286-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0198-0001.jpeg
#   inflating: Dataset_/Normal/N NNORMAL (1015).png
#   inflating: Dataset_/Normal/N NNORMAL (1025).png
#   inflating: Dataset_/Normal/N NNORMAL (102).png
#   inflating: Dataset_/Normal/N NNORMAL (1003).png
#   inflating: Dataset_/Normal/N NNORMAL (1014).png
#   inflating: Dataset_/Normal/N NNORMAL (1046).png
#   inflating: Dataset_/Normal/N NNORMAL (103).png
#   inflating: Dataset_/Normal/N NNORMAL (1024).png
#   inflating: Dataset_/Normal/N NNORMAL (1029).png
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0145-0001.jpeg
#   inflating: Dataset_/Normal/N NNORMAL (1000).png
#   inflating: Dataset_/Normal/N NNORMAL (1021).png
#   inflating: Dataset_/Normal/N NNORMAL (1006).png
#   inflating: Dataset_/Normal/N NNORMAL (1056).png
#   inflating: Dataset_/Normal/N NNORMAL (1010).png
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0221-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0058-0001.jpeg
#   inflating: Dataset_/Normal/N NNORMAL (1012).png
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0079-0001.jpeg
#   inflating: Dataset_/Normal/N NNORMAL (1033).png
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0304-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0328-0001.jpeg
#   inflating: Dataset_/Normal/N NNORMAL (1).png
#   inflating: Dataset_/Normal/N NNORMAL (1004).png
#   inflating: Dataset_/Normal/N NNORMAL (1009).png
#   inflating: Dataset_/Normal/N NNORMAL (101).png
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0373-0001.jpeg
#   inflating: Dataset_/Normal/Q_IM-0043-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0310-0001.jpeg
#   inflating: Dataset_/Normal/N NNORMAL (1036).png
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0246-0001-0001.jpeg
#   inflating: Dataset_/Normal/N NNORMAL (1011).png
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0331-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0292-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0173-0001-0001.jpeg
#   inflating: Dataset_/Normal/N NNORMAL (1008).png
#   inflating: Dataset_/Normal/Q_IM-0093-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0346-0001.jpeg
#   inflating: Dataset_/Normal/Q_IM-0111-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0325-0001.jpeg
#   inflating: Dataset_/Normal/N NNORMAL (1005).png
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0256-0001.jpeg
#   inflating: Dataset_/Normal/Q_IM-0001-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0107-0001.jpeg
#   inflating: Dataset_/Normal/Q_IM-0015-0001.jpeg
#   inflating: Dataset_/Normal/Q_IM-0105-0001.jpeg
#   inflating: Dataset_/Normal/N NNORMAL (1007).png
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0354-0001.jpeg
#   inflating: Dataset_/Normal/Q_IM-0039-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0238-0001.jpeg
#   inflating: Dataset_/Normal/Q_IM-0045-0001.jpeg
#   inflating: Dataset_/Normal/N NNORMAL (1001).png
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0294-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0340-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0206-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0195-0001.jpeg
#   inflating: Dataset_/Normal/Q_IM-0011-0001-0002.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0041-0001.jpeg
#   inflating: Dataset_/Normal/Q_IM-0081-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0359-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0029-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0132-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0139-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0060-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0249-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0120-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0277-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0316-0001.jpeg
#   inflating: Dataset_/Normal/Q_IM-0087-0001.jpeg
#   inflating: Dataset_/Normal/Q_IM-0103-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0030-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0352-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0378-0001.jpeg
#   inflating: Dataset_/Normal/Q_IM-0095-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0302-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0219-0001.jpeg
#   inflating: Dataset_/Normal/Q_IM-0007-0001.jpeg
#   inflating: Dataset_/Normal/Q_IM-0070-0001.jpeg
#   inflating: Dataset_/COVID-19/COVID (338).png
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0066-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0271-0001.jpeg
#   inflating: Dataset_/Normal/Q_IM-0013-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0361-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0072-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0323-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0199-0001.jpeg
#   inflating: Dataset_/COVID-19/COVID (530).png
#   inflating: Dataset_/Normal/Q_IM-0063-0001.jpeg
#   inflating: Dataset_/COVID-19/COVID (388).png
#   inflating: Dataset_/COVID-19/COVID (489).png
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0287-0001.jpeg
#   inflating: Dataset_/Normal/Q_IM-0019-0001.jpeg
#   inflating: Dataset_/COVID-19/COVID (283).png
#   inflating: Dataset_/Normal/Q_IM-0077-0001.jpeg
#   inflating: Dataset_/COVID-19/COVID (325).png
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0150-0001.jpeg
#   inflating: Dataset_/Normal/Q_IM-0069-0001.jpeg
#   inflating: Dataset_/COVID-19/COVID (455).png
#   inflating: Dataset_/COVID-19/COVID (18).png
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0329-0001.jpeg
#   inflating: Dataset_/COVID-19/COVID (477).png
#   inflating: Dataset_/COVID-19/COVID (183).png
#   inflating: Dataset_/COVID-19/COVID (296).png
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0337-0001.jpeg
#   inflating: Dataset_/COVID-19/COVID (140).png
#   inflating: Dataset_/COVID-19/COVID (132).png
#   inflating: Dataset_/COVID-19/COVID (649).png
#   inflating: Dataset_/COVID-19/COVID (648).png
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0347-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0372-0001.jpeg
#   inflating: Dataset_/COVID-19/COVID (539).png
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0366-0001.jpeg
#   inflating: Dataset_/COVID-19/COVID (606).png
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0171-0001.jpeg
#   inflating: Dataset_/COVID-19/COVID (500).png
#   inflating: Dataset_/COVID-19/COVID (245).png
#   inflating: Dataset_/COVID-19/COVID (452).png
#   inflating: Dataset_/COVID-19/COVID (187).png
#   inflating: Dataset_/COVID-19/COVID (220).png
#   inflating: Dataset_/COVID-19/COVID (444).png
#   inflating: Dataset_/COVID-19/COVID (305).png
#   inflating: Dataset_/Normal/Q_IM-0110-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0305-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0233-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0353-0001.jpeg
#   inflating: Dataset_/Normal/Q_IM-0021-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1246).png
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0280-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0112-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (119).png
#   inflating: Dataset_/Normal/Q_IM-0086-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0201-0001.jpeg
#   inflating: Dataset_/COVID-19/COVID (657).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1214).png
#   inflating: Dataset_/COVID-19/COVID (261).png
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0207-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1183).png
#   inflating: Dataset_/Normal/N NNORMAL (1313).png
#   inflating: Dataset_/Normal/N NNORMAL (125).png
#   inflating: Dataset_/Normal/Q_IM-0109-0001.jpeg
#   inflating: Dataset_/Normal/Q_IM-0050-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1208).png
#   inflating: Dataset_/Normal/Q_IM-0102-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0276-0001.jpeg
#   inflating: Dataset_/Normal/N NNORMAL (1044).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1287).png
#   inflating: Dataset_/Normal/N NNORMAL (579).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (244).png
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0213-0001.jpeg
#   inflating: Dataset_/COVID-19/COVID (737).png
#   inflating: Dataset_/COVID-19/COVID (693).png
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0330-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (614).png
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0374-0001-0002.jpeg
#   inflating: Dataset_/Normal/N NNORMAL (431).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1202).png
#   inflating: Dataset_/COVID-19/COVID (824).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1194).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1212).png
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0311-0001.jpeg
#   inflating: Dataset_/Normal/Q_IM-0035-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1288).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1232).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (716).png
#   inflating: Dataset_/Normal/N NNORMAL (261).png
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0023-0001.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person363_bacteria_1655.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1216).png
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0059-0001.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person1215_bacteria_3167.jpeg
#   inflating: Dataset_/Normal/N NNORMAL (266).png
#   inflating: Dataset_/Bacterial Pneumonia/Q_person1379_bacteria_3514.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (709).png
#   inflating: Dataset_/Bacterial Pneumonia/Q_person1349_bacteria_3436.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (581).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (492).png
#   inflating: Dataset_/COVID-19/COVID (801).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (355).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1283).png
#   inflating: Dataset_/COVID-19/COVID (679).png
#   inflating: Dataset_/Normal/N NNORMAL (187).png
#   inflating: Dataset_/Bacterial Pneumonia/Q_person1481_bacteria_3863.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person277_bacteria_1306.jpeg
#   inflating: Dataset_/COVID-19/COVID (690).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (569).png
#   inflating: Dataset_/Normal/N NNORMAL (1016).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (706).png
#   inflating: Dataset_/Bacterial Pneumonia/Q_person548_bacteria_2297.jpeg
#   inflating: Dataset_/Normal/N NNORMAL (592).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (217).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (145).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1238).png
#   inflating: Dataset_/COVID-19/COVID (235).png
#   inflating: Dataset_/Normal/N NNORMAL (1259).png
#   inflating: Dataset_/Normal/N NNORMAL (1213).png
#   inflating: Dataset_/COVID-19/COVID (909).png
#   inflating: Dataset_/COVID-19/COVID (51).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1233).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1189).png
#   inflating: Dataset_/COVID-19/COVID (716).png
#   inflating: Dataset_/Bacterial Pneumonia/Q_person537_bacteria_2265.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1225).png
#   inflating: Dataset_/COVID-19/COVID (162).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1185).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (251).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1236).png
#   inflating: Dataset_/Normal/N NNORMAL (280).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1203).png
#   inflating: Dataset_/Normal/N NNORMAL (1314).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (712).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1201).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (53).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1229).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1181).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (12).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1207).png
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0052-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (122).png
#   inflating: Dataset_/Normal/Q_IM-0033-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0281-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0028-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1211).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1239).png
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0232-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1226).png
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0317-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1235).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1204).png
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0374-0001.jpeg
#   inflating: Dataset_/Normal/Q_IM-0065-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1222).png
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0360-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1198).png
#   inflating: Dataset_/Normal/Q_IM-0049-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0251-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1205).png
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0135-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0096-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1227).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1197).png
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0303-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0073-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1218).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1182).png
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0290-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1192).png
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0336-0001.jpeg
#   inflating: Dataset_/Normal/Q_IM-0027-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1221).png
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0322-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (120).png
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0129-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1210).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1190).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1196).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1191).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1223).png
#   inflating: Dataset_/Normal/Q_IM-0085-0001.jpeg
#   inflating: Dataset_/Normal/Q_IM-0041-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1199).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1220).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1219).png
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0350-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1184).png
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0380-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0259-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1193).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1234).png
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0237-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0278-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1206).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1217).png
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0111-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0327-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1228).png
#   inflating: Dataset_/Normal/Q_IM-0071-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0275-0001.jpeg
#   inflating: Dataset_/Normal/Q_IM-0022-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1187).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1130).png
#   inflating: Dataset_/Normal/Q_IM-0091-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1164).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1149).png
#   inflating: Dataset_/Normal/Q_IM-0107-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0349-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (115).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1213).png
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0319-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0368-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1125).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1124).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1145).png
#   inflating: Dataset_/Normal/Q_IM-0036-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1126).png
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0105-0001.jpeg
#   inflating: Dataset_/Normal/Q_IM-0003-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0130-0001.jpeg
#   inflating: Dataset_/Normal/Q_IM-0006-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (116).png
#   inflating: Dataset_/Normal/Q_IM-0033-0001-0002.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1175).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1177).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (113).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1165).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1128).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1160).png
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0374-0001-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1167).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1134).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1174).png
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0312-0001.jpeg
#   inflating: Dataset_/Normal/Q_IM-0079-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0007-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0333-0001.jpeg
#   inflating: Dataset_/Normal/Q_IM-0017-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1156).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1178).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1138).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1151).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1140).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1129).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1137).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (117).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1148).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1155).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1139).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1143).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1157).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (41).png
#   inflating: Dataset_/Normal/N NNORMAL (441).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1159).png
#   inflating: Dataset_/Normal/N NNORMAL (59).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1173).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (114).png
#   inflating: Dataset_/COVID-19/COVID (791).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (118).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1133).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1152).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1179).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1150).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1171).png
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0289-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1141).png
#   inflating: Dataset_/Normal/N NNORMAL (60).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1163).png
# ...
#   inflating: Dataset_/Bacterial Pneumonia/Q_person60_bacteria_287.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person1147_virus_1917.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person449_bacteria_1940.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person1415_bacteria_3629.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person891_virus_1541.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person1110_virus_1835.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person472_bacteria_2015.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person69_bacteria_338.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person1222_bacteria_3177.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person1598_bacteria_4197.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person688_bacteria_2584.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person616_bacteria_2487.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person437_bacteria_1887.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person671_virus_1260.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person281_bacteria_1329.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person1619_bacteria_4261.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person890_bacteria_2814.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0876-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0881-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0877-0001.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person1253_bacteria_3211.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person1484_virus_2577.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person1488_virus_2587.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person509_virus_1025.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0563-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0880-0001.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person321_bacteria_1489.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person154_virus_306.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person1115_virus_1840.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0564-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0566-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person1451_virus_2479.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person1816_bacteria_4674.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person952_virus_1623.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0886-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person401_virus_797.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0558-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person366_virus_746.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person465_bacteria_1980.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0571-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person701_virus_1297.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person317_virus_643.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0568-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0567-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person1024_virus_1716.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person581_bacteria_2392.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person1812_bacteria_4667.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person779_virus_1410.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1230).png
#   inflating: Dataset_/Bacterial Pneumonia/Q_person47_bacteria_229.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0892-0001.jpeg
#   inflating: Dataset_/Normal/N NNORMAL (591).png
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0887-0001.jpeg
#   inflating: Dataset_/Normal/N NNORMAL (1077).png
#   inflating: Dataset_/COVID-19/COVID (862).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (1277).png
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0885-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person978_virus_1653.jpeg
#   inflating: Dataset_/Normal/N NNORMAL (1279).png
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0879-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0569-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0882-0001.jpeg
#   inflating: Dataset_/COVID-19/COVID (403).png
#   inflating: Dataset_/Bacterial Pneumonia/Q_person755_bacteria_2659.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person1063_virus_1765.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person1214_bacteria_3166.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person1438_bacteria_3721.jpeg
#   inflating: Dataset_/COVID-19/COVID (142).png
#   inflating: Dataset_/Normal/Q_IM-0617-0001.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person63_bacteria_306.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0890-0001.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person61_bacteria_295.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person359_bacteria_1644.jpeg
#   inflating: Dataset_/Normal/Q_IM-0083-0001.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person62_bacteria_300.jpeg
#   inflating: Dataset_/Normal/Q_IM-0307-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (243).png
#   inflating: Dataset_/Bacterial Pneumonia/Q_person276_bacteria_1296.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person1274_virus_2193.jpeg
#   inflating: Dataset_/Normal/Q_IM-0761-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person137_virus_281.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0765-0001.jpeg
#   inflating: Dataset_/Normal/N NNORMAL (258).png
#   inflating: Dataset_/Bacterial Pneumonia/Q_person321_bacteria_1485.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person1452_virus_2484.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/VP Viral Pneumonia (402).png
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0888-0001.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person661_bacteria_2553.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person1366_virus_2349.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person682_virus_1273.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person639_virus_1220.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person1491_bacteria_3893.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person26_bacteria_122.jpeg
#   inflating: Dataset_/Normal/Q_IM-0548-0001.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person357_bacteria_1640.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person342_virus_702.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person441_virus_896.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person309_virus_632.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person124_virus_234.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person107_virus_197.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person264_virus_547.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person870_virus_1516.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person1602_virus_2780.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person378_virus_761.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person849_virus_1494.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person878_virus_1526.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person937_virus_1599.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person104_virus_191.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person1010_virus_1695.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person521_virus_1040.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person1474_virus_2557.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person362_virus_741.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person1294_virus_2222.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person1593_virus_2767.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person579_virus_1123.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person592_virus_1141.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person1381_virus_2375.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person813_virus_1449.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person765_virus_1393.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person1112_virus_1837.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person571_virus_1114.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person445_virus_916.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0908-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person88_virus_165.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0912-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person509_virus_1024.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person1311_virus_2259.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0915-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person596_virus_1149.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0914-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person353_virus_728.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person1549_virus_2690.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0913-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0918-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person346_virus_708.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person125_virus_254.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person338_virus_694.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person484_virus_986.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person388_virus_777.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person290_virus_594.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person1459_virus_2506.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person460_virus_948.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person1007_virus_1690.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person647_virus_1228.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0925-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person1403_virus_2406.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0924-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person757_virus_1385.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person1224_virus_2074.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0929-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0910-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0917-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0923-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0932-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0909-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person600_virus_1156.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0934-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person333_virus_688.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person96_virus_179.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0922-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person598_virus_1154.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person1291_virus_2217.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person339_virus_695.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person1492_virus_2599.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person469_virus_965.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person357_virus_734.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0911-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0919-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0933-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person991_virus_1669.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0930-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person385_virus_770.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0935-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0937-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person673_virus_1263.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person798_virus_1430.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0926-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person461_virus_949.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person392_virus_782.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person935_virus_1597.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person97_virus_181.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person1242_virus_2108.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person1375_virus_2366.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0947-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0931-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person519_virus_1038.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0948-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0950-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0936-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0946-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person1317_virus_2273.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person968_virus_1642.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0927-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0954-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person1107_virus_1832.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person806_virus_1440.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0952-0001.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-0939-0001.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person753_virus_1378.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person407_virus_811.jpeg
#   inflating: Dataset_/Normal/Q_NORMAL2-IM-1241-0001.jpeg
#   inflating: Dataset_/COVID-19/COVID (319).png
#   inflating: Dataset_/Bacterial Pneumonia/Q_person441_bacteria_1902.jpeg
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person1142_virus_1892.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person1689_bacteria_4473.jpeg
#   inflating: Dataset_/COVID-19/COVID (28).png
#   inflating: Dataset_/COVID-19/COVID (545).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person906_virus_1562.jpeg
#   inflating: Dataset_/COVID-19/COVID (447).png
#   inflating: Dataset_/Non-COVID Viral Pneumonia/Q_person1298_virus_2228.jpeg
#   inflating: Dataset_/COVID-19/COVID (82).png
#   inflating: Dataset_/COVID-19/COVID (346).png
#   inflating: Dataset_/COVID-19/COVID (605).png
#   inflating: Dataset_/COVID-19/COVID (336).png
#   inflating: Dataset_/Bacterial Pneumonia/Q_person1722_bacteria_4547.jpeg
#   inflating: Dataset_/COVID-19/COVID (214).png
#   inflating: Dataset_/Bacterial Pneumonia/Q_person253_bacteria_1152.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person387_bacteria_1770.jpeg
#   inflating: Dataset_/COVID-19/COVID (311).png
#   inflating: Dataset_/Bacterial Pneumonia/Q_person415_bacteria_1838.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person1486_bacteria_3884.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person1311_bacteria_3312.jpeg
#   inflating: Dataset_/COVID-19/COVID (71).png
#   inflating: Dataset_/COVID-19/COVID (252).png
#   inflating: Dataset_/Bacterial Pneumonia/Q_person580_bacteria_2389.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person1709_bacteria_4523.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person1719_bacteria_4542.jpeg
#   inflating: Dataset_/Bacterial Pneumonia/Q_person592_bacteria_2434.jpeg
#   inflating: Dataset_/COVID-19/COVID (114).png

# %%
# Creates a folder for training and testing sets
# !mkdir test
# !mkdir train
# !mkdir "train/Non-COVID Viral Pneumonia"
# !mkdir "train/COVID-19"
# !mkdir "train/Normal"
# !mkdir "train/Bacterial Pneumonia"
# !mkdir "test/Non-COVID Viral Pneumonia"
# !mkdir "test/COVID-19"
# !mkdir "test/Normal"
# !mkdir "test/Bacterial Pneumonia"

# %%
# Divide files into training and testing folders
# IMG_PATH = 'covid19dataset/' # unzipped folder
IMG_PATH = 'Dataset_/' # unzipped folder

print(IMG_PATH)
import os, shutil
# split the data by train/test
for CLASS in os.listdir(IMG_PATH):
    if not CLASS.startswith('.'):
      dir  = os.path.isdir(IMG_PATH + CLASS)
      if dir:
        IMG_NUM = len(os.listdir(IMG_PATH + CLASS))
        for (n, FILE_NAME) in enumerate(os.listdir(IMG_PATH + CLASS)):
            img = IMG_PATH + CLASS + '/' + FILE_NAME
            if n < 0.8*IMG_NUM:
                shutil.copy(img, 'train/' + CLASS + '/' + FILE_NAME)
            else:
                shutil.copy(img, 'test/'+ CLASS + '/' + FILE_NAME)
# Out:
# Dataset_/

# %%
# dimensions of our images
img_width, img_height = 224, 224
img_size = (224, 224)

# Saving the batch_size and epochs for training to variables
batch_size = 16 #usually in powers of 2 - 8, 16, 32, 64, 128
epochs = 50
lr = 0.0001.
class_array = ['Normal', 'COVID-19', 'Non-COVID Viral Pneumonia']
num_classes = len(class_array)

train_file_count = sum(len(files) for _, _, files in os.walk(r'train'))
test_file_count = sum(len(files) for _, _, files in os.walk(r'test'))

print("Number of files in train set ", train_file_count)
print("Number of files in test set ", test_file_count)
# Out:
# Number of files in train set  6744
# Number of files in test set  1684

# %%
train_datagen = ImageDataGenerator(rescale=1./255, # normalization - tranforms pixel value from 0 - 255 to 0 - 1
                                   validation_split=0.15,
                                   shear_range = 0.2, # extent of shearing - 20%
                                   zoom_range = 0.2, # extent of adjusting the zoom in images - 20%
                                   horizontal_flip= True, # randomly flipping to get mirror images
                                   rotation_range=0.1) # turns the image - 10%

valid_datagen = ImageDataGenerator(rescale=1./255,
                                   validation_split=0.15)

# %%
# Create a flow from the directory using same seed and 'training' subset.
train_generator = train_datagen.flow_from_directory('train',
                                              subset='training',
                                              shuffle=True,
                                              seed=42,
                                              target_size=img_size,
                                              batch_size=batch_size,
                                              class_mode='categorical',
                                              classes = class_array)

# Create a flow from the directory for validation data - seed=42
validation_generator = valid_datagen.flow_from_directory('train',
                                              subset='validation',
                                              seed=42,
                                              target_size=img_size,
                                              batch_size = batch_size,
                                              class_mode='categorical',
                                              classes = class_array)
# Out:
# Found 4136 images belonging to 3 classes.
# Found 728 images belonging to 3 classes.

# %% [markdown]
# ###DenseNet201

# %%
from tensorflow.keras.applications import DenseNet201

densenet201_pre_trained_model = DenseNet201(input_shape = (224,224,3),
                              include_top = False, # not using the classification that is happening in the model
                              weights = 'imagenet') # use weights that the models were trained for
                              # weights -

for layer in densenet201_pre_trained_model.layers:
    layer.trainable = False # for each layer in the pre-trained model, each layer isn't being trained since the weights are already being used --- no need to retrain again

densenet201_pre_trained_model.summary()

# %%
def build_my_model(model_name):

    new_model = Sequential()
    model = model_name
    new_model.add(model)
    new_model.add(Flatten()) # flattens into a 1D array....
    new_model.add(Dense(1024, activation='relu')) # kind of like a connection between layers?? -- helps with extracting features
    new_model.add(Dropout(0.1)) # random nodes(weights) are dropped out --> weights are made to 0 -- helps reduce overfitting
    # overfitting is when the model can predict the training data set very accurately but might fail with a new unknown dataset
    new_model.add(Dense(512, activation='relu')) # activation function send out the output - relu (rectified linear unit) ReLU - _/-
    new_model.add(Dropout(0.1))
    new_model.add(Dense(256, activation='relu'))
    new_model.add(Dropout(0.1))
    new_model.add(Dense(num_classes, activation='softmax')) # softmax is like cubic function - used for classifying >=3
    return new_model

my_densenet201_model = build_my_model(densenet201_pre_trained_model) # building a model based on the densenet201

my_densenet201_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# densenet201 (Functional)     (None, 7, 7, 1920)        18321984
# _________________________________________________________________
# flatten (Flatten)            (None, 94080)             0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              96338944
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 771
# =================================================================
# Total params: 115,317,827
# Trainable params: 96,995,843
# Non-trainable params: 18,321,984
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping

optimizer = Adam(lr = lr) # RMSprop(learning_rate=1e-4)
loss = 'categorical_crossentropy' # categorical because we are classifying into more than 2. if it were 2, it would binary crossentropy -------- is a synonym to softmax loss
metrics = ['accuracy']

weight_path = "densenet201_b16_bestweights.hdf5".format('class')

checkpoint = ModelCheckpoint(weight_path,
                             monitor = 'val_loss',
                             verbose = 1,
                             save_best_only = True,
                             mode = 'auto',
                             save_weights_only = True)

early = EarlyStopping(monitor= 'val_loss',
                      mode= 'auto',
                      patience=10) # if loss doesn't improve for 10 epochs straight, model stops training

callbacks_list = [checkpoint, early] # creates a checkpoint between each epoch


my_densenet201_model.compile(optimizer=optimizer, loss=loss, metrics=metrics) # compiling model

history = my_densenet201_model.fit(train_generator,
                          validation_data = validation_generator,
                          batch_size = batch_size,
                          epochs = epochs,
                          callbacks = callbacks_list)
# Out:
# Epoch 1/50
# 259/259 [==============================] - 118s 425ms/step - loss: 0.0587 - accuracy: 0.9821 - val_loss: 0.1633 - val_accuracy: 0.9437
#
# Epoch 00001: val_loss improved from inf to 0.16330, saving model to densenet201_b16_bestweights.hdf5
# Epoch 2/50
# 259/259 [==============================] - 108s 416ms/step - loss: 0.0567 - accuracy: 0.9814 - val_loss: 0.2961 - val_accuracy: 0.9217
#
# Epoch 00002: val_loss did not improve from 0.16330
# Epoch 3/50
# 259/259 [==============================] - 109s 419ms/step - loss: 0.0531 - accuracy: 0.9786 - val_loss: 0.1348 - val_accuracy: 0.9574
#
# Epoch 00003: val_loss improved from 0.16330 to 0.13484, saving model to densenet201_b16_bestweights.hdf5
# Epoch 4/50
# 259/259 [==============================] - 108s 418ms/step - loss: 0.0368 - accuracy: 0.9823 - val_loss: 0.4132 - val_accuracy: 0.8970
#
# Epoch 00004: val_loss did not improve from 0.13484
# Epoch 5/50
# 259/259 [==============================] - 109s 422ms/step - loss: 0.0546 - accuracy: 0.9785 - val_loss: 0.1904 - val_accuracy: 0.9354
#
# Epoch 00005: val_loss did not improve from 0.13484
# Epoch 6/50
# 259/259 [==============================] - 109s 421ms/step - loss: 0.0377 - accuracy: 0.9875 - val_loss: 0.1735 - val_accuracy: 0.9478
#
# Epoch 00006: val_loss did not improve from 0.13484
# Epoch 7/50
# 259/259 [==============================] - 110s 423ms/step - loss: 0.0356 - accuracy: 0.9865 - val_loss: 0.0987 - val_accuracy: 0.9712
#
# Epoch 00007: val_loss improved from 0.13484 to 0.09867, saving model to densenet201_b16_bestweights.hdf5
# Epoch 8/50
# 259/259 [==============================] - 111s 426ms/step - loss: 0.0433 - accuracy: 0.9838 - val_loss: 0.0834 - val_accuracy: 0.9725
#
# Epoch 00008: val_loss improved from 0.09867 to 0.08337, saving model to densenet201_b16_bestweights.hdf5
# Epoch 9/50
# 259/259 [==============================] - 111s 427ms/step - loss: 0.0459 - accuracy: 0.9829 - val_loss: 0.1032 - val_accuracy: 0.9684
#
# Epoch 00009: val_loss did not improve from 0.08337
# Epoch 10/50
# 259/259 [==============================] - 109s 421ms/step - loss: 0.0394 - accuracy: 0.9858 - val_loss: 0.0627 - val_accuracy: 0.9766
#
# Epoch 00010: val_loss improved from 0.08337 to 0.06274, saving model to densenet201_b16_bestweights.hdf5
# Epoch 11/50
# 259/259 [==============================] - 110s 426ms/step - loss: 0.0363 - accuracy: 0.9876 - val_loss: 0.0968 - val_accuracy: 0.9712
#
# Epoch 00011: val_loss did not improve from 0.06274
# Epoch 12/50
# 259/259 [==============================] - 107s 411ms/step - loss: 0.0357 - accuracy: 0.9883 - val_loss: 0.0822 - val_accuracy: 0.9739
#
# Epoch 00012: val_loss did not improve from 0.06274
# Epoch 13/50
# 259/259 [==============================] - 107s 414ms/step - loss: 0.0314 - accuracy: 0.9875 - val_loss: 0.1173 - val_accuracy: 0.9657
#
# Epoch 00013: val_loss did not improve from 0.06274
# Epoch 14/50
# 259/259 [==============================] - 109s 421ms/step - loss: 0.0316 - accuracy: 0.9886 - val_loss: 0.0857 - val_accuracy: 0.9712
#
# Epoch 00014: val_loss did not improve from 0.06274
# Epoch 15/50
# 259/259 [==============================] - 109s 420ms/step - loss: 0.0364 - accuracy: 0.9858 - val_loss: 0.0771 - val_accuracy: 0.9712
#
# Epoch 00015: val_loss did not improve from 0.06274
# Epoch 16/50
# 259/259 [==============================] - 108s 415ms/step - loss: 0.0358 - accuracy: 0.9878 - val_loss: 0.0764 - val_accuracy: 0.9684
#
# Epoch 00016: val_loss did not improve from 0.06274
# Epoch 17/50
# 259/259 [==============================] - 108s 417ms/step - loss: 0.0366 - accuracy: 0.9879 - val_loss: 0.1486 - val_accuracy: 0.9602
#
# Epoch 00017: val_loss did not improve from 0.06274
# Epoch 18/50
# 259/259 [==============================] - 108s 416ms/step - loss: 0.0368 - accuracy: 0.9865 - val_loss: 0.0608 - val_accuracy: 0.9753
#
# Epoch 00018: val_loss improved from 0.06274 to 0.06075, saving model to densenet201_b16_bestweights.hdf5
# Epoch 19/50
# 259/259 [==============================] - 111s 428ms/step - loss: 0.0313 - accuracy: 0.9872 - val_loss: 0.1943 - val_accuracy: 0.9368
#
# Epoch 00019: val_loss did not improve from 0.06075
# Epoch 20/50
# 259/259 [==============================] - 107s 415ms/step - loss: 0.0320 - accuracy: 0.9883 - val_loss: 0.2363 - val_accuracy: 0.9272
#
# Epoch 00020: val_loss did not improve from 0.06075
# Epoch 21/50
# 259/259 [==============================] - 106s 408ms/step - loss: 0.0333 - accuracy: 0.9887 - val_loss: 0.0879 - val_accuracy: 0.9684
#
# Epoch 00021: val_loss did not improve from 0.06075
# Epoch 22/50
# 259/259 [==============================] - 108s 416ms/step - loss: 0.0467 - accuracy: 0.9842 - val_loss: 0.0552 - val_accuracy: 0.9794
#
# Epoch 00022: val_loss improved from 0.06075 to 0.05516, saving model to densenet201_b16_bestweights.hdf5
# Epoch 23/50
# 259/259 [==============================] - 105s 406ms/step - loss: 0.0265 - accuracy: 0.9897 - val_loss: 0.0891 - val_accuracy: 0.9684
#
# Epoch 00023: val_loss did not improve from 0.05516
# Epoch 24/50
# 259/259 [==============================] - 106s 408ms/step - loss: 0.0242 - accuracy: 0.9928 - val_loss: 0.1068 - val_accuracy: 0.9698
#
# Epoch 00024: val_loss did not improve from 0.05516
# Epoch 25/50
# 259/259 [==============================] - 105s 407ms/step - loss: 0.0300 - accuracy: 0.9893 - val_loss: 0.0645 - val_accuracy: 0.9780
#
# Epoch 00025: val_loss did not improve from 0.05516
# Epoch 26/50
# 259/259 [==============================] - 105s 406ms/step - loss: 0.0308 - accuracy: 0.9890 - val_loss: 0.0640 - val_accuracy: 0.9794
#
# Epoch 00026: val_loss did not improve from 0.05516
# Epoch 27/50
# 259/259 [==============================] - 106s 408ms/step - loss: 0.0320 - accuracy: 0.9896 - val_loss: 0.1808 - val_accuracy: 0.9505
#
# Epoch 00027: val_loss did not improve from 0.05516
# Epoch 28/50
# 259/259 [==============================] - 104s 400ms/step - loss: 0.0489 - accuracy: 0.9841 - val_loss: 0.0693 - val_accuracy: 0.9794
#
# Epoch 00028: val_loss did not improve from 0.05516
# Epoch 29/50
# 259/259 [==============================] - 106s 411ms/step - loss: 0.0199 - accuracy: 0.9935 - val_loss: 0.1290 - val_accuracy: 0.9629
#
# Epoch 00029: val_loss did not improve from 0.05516
# Epoch 30/50
# 259/259 [==============================] - 105s 404ms/step - loss: 0.0262 - accuracy: 0.9924 - val_loss: 0.1040 - val_accuracy: 0.9712
#
# Epoch 00030: val_loss did not improve from 0.05516
# Epoch 31/50
# 259/259 [==============================] - 106s 408ms/step - loss: 0.0173 - accuracy: 0.9938 - val_loss: 0.1444 - val_accuracy: 0.9533
#
# Epoch 00031: val_loss did not improve from 0.05516
# Epoch 32/50
# 259/259 [==============================] - 105s 406ms/step - loss: 0.0254 - accuracy: 0.9910 - val_loss: 0.0987 - val_accuracy: 0.9766
#
# Epoch 00032: val_loss did not improve from 0.05516

# %%
DenseNet_model_json = my_densenet201_model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(DenseNet_model_json)

# serialize weights to HDF5
my_densenet201_model.save_weights("model.h5")
print("Saved model to disk")

# save model and architecture to single file
my_densenet201_model.save("my_densenet201_model_b16.h5")
print("Saved full model to disk")
# Out:
# Saved model to disk
# Saved full model to disk

# %%
# prints what the history has stored (stored in a dictionary format (key-value pairs))
print(history.history.keys())

# summarize history for accuracy on a line chart
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# summarize history for loss on a line chart
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
json_file = open('model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("model.h5")
print("Loaded model from disk")
# Out:
# Loaded model from disk

# %%
from keras.models import load_model #to load the model saved as a h5 file
# load model
densenet201_full_model = build_my_model(densenet201_pre_trained_model)

densenet201_full_model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

densenet201_full_model.load_weights('densenet201_b16_bestweights.hdf5')
# summarize model.
densenet201_full_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# densenet201 (Functional)     (None, 7, 7, 1920)        18321984
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 94080)             0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1024)              96338944
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 3)                 771
# =================================================================
# Total params: 115,317,827
# Trainable params: 96,995,843
# Non-trainable params: 18,321,984
# _________________________________________________________________

# %%
test_datagen = ImageDataGenerator(rescale=1./255)

# Create a flow from the directory for validation data - seed=42
test_generator = test_datagen.flow_from_directory('test',
                                              target_size= (224,224),
                                              batch_size = 1,
                                              shuffle = False,
                                              class_mode='categorical',
                                              classes = class_array)
# Out:
# Found 1214 images belonging to 3 classes.

# %%
my_densenet201_model.evaluate(test_generator) # using model on testing dataset
# Out:
# 1214/1214 [==============================] - 31s 25ms/step - loss: 0.1840 - accuracy: 0.9596
# [0.1840304434299469, 0.9596375823020935]

# %%
densenet201_full_model.evaluate(test_generator) # best weights
# Out:
# 1214/1214 [==============================] - 35s 25ms/step - loss: 0.1319 - accuracy: 0.9809
# [0.17634093761444092, 0.9703459739685059]

# %%
from sklearn.metrics import accuracy_score,classification_report, confusion_matrix # ask parents

y_true = test_generator.classes
probabilities = my_densenet201_model.predict(test_generator)
y_pred = probabilities.argmax(axis = 1)
# Classification report will show us precision, recall and F1 Score of the model
print(classification_report(y_true, y_pred))

accuracy = accuracy_score(y_true, y_pred)
print('accuracy: ', accuracy)

conf_mat = confusion_matrix(y_true, y_pred)
print(conf_mat)

cm_df = pd.DataFrame(conf_mat,
                     index = class_array,
                     columns = class_array)

plt.figure()
sns.heatmap(cm_df, annot=True, square=True, cbar=False, fmt="d")
plt.title('Covid19 Confusion Matrix - CNN Model')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# %%
from sklearn.metrics import accuracy_score,classification_report, confusion_matrix

y_true = test_generator.classes
probabilities = densenet201_full_model.predict(test_generator)
y_pred = probabilities.argmax(axis = 1)
# Classification report will show us precision, recall and F1 Score of the model
print(classification_report(y_true, y_pred))

accuracy = accuracy_score(y_true, y_pred)
print('accuracy: ', accuracy)

conf_mat = confusion_matrix(y_true, y_pred)
print(conf_mat)

cm_df = pd.DataFrame(conf_mat,
                     index = class_array,
                     columns = class_array)

plt.figure()
sns.heatmap(cm_df, annot=True, square=True, cbar=False, fmt="d")
plt.title('Covid19 Confusion Matrix - CNN Model')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96       462
#            1       0.97      0.99      0.98       258
#            2       0.98      0.97      0.97       494
#
#     accuracy                           0.97      1214
#    macro avg       0.97      0.97      0.97      1214
# weighted avg       0.97      0.97      0.97      1214
#
# accuracy:  0.9703459637561779
# [[446   6  10]
#  [  1 255   2]
#  [ 16   1 477]]

# %%
# !cp densenet201_b16_bestweights.hdf5 "/content/gdrive/MyDrive/Science Fair"
# !cp my_densenet201_model_b16.h5 "/content/gdrive/MyDrive/Science Fair"

# %%
# !nvidia-smi
# Out:
# Mon Mar  1 07:09:31 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
